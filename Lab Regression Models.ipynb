# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
student_data = pd.DataFrame({'Age': [17,51,27,21,36,48,19,26,54,30], 'Tardies': [10,1,5,9,4,2,9,6,0,3]})

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
plt.scatter(student_data['Age'], student_data['Tardies'],  color='black')
plt.xlabel("Age") ; plt.ylabel("Tardies") ; plt.show()

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
"Cuánto más joven es el alumno, más propenso a llegar tarde y cuánto más viejo es el alumno, menos propenso a llegar tarde."
# Out:
# 'Cuánto más joven es el alumno, más propenso a llegar tarde y cuánto más viejo es el alumno, menos propenso a llegar tarde.'

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
print(f" La covarianza es {student_data['Age'].cov(student_data['Tardies'])}")
print(f" La correlación es {student_data['Age'].corr(student_data['Tardies'])}")
"La correlación es bastante alta, por lo que podemos decir que existe una relación lineal entre la edad y la llegada tarde, además la covarianza es negativa, lo que indica que la relación es inversamente proporcional."
# Out:
#  La covarianza es -45.56666666666667
#  La correlación es -0.9391626886887122
# 'La correlación es bastante alta, por lo que podemos decir que existe una relación lineal entre la edad y la llegada tarde, además la covarianza es negativa, lo que indica que la relación es inversamente proporcional.'

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
X = student_data['Age'].values.reshape(-1,1)
Y = student_data['Tardies'].values.reshape(-1,1)
reg = LinearRegression().fit(X, Y)

"Estoy usando la función de regresión lineal de sklearn para obtener los coeficientes de la recta de regresión, ya que en el modelo de dispersión se ve que la relación es lineal."
# Out:
# 'Estoy usando la función de regresión lineal de sklearn para obtener los coeficientes de la recta de regresión, ya que en el modelo de dispersión se ve que la relación es lineal.'

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
plt.scatter(X, Y)
plt.plot(X, reg.predict(X), color='red', linewidth=3)
plt.xlabel("Age") ; plt.ylabel("Tardies") ; plt.show()

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
"Los resultados del modelo nos indican que la edad es un buen predictor de la llegada tarde, ya que la recta de regresión se ajusta bastante bien a los datos. Además, la correlación es bastante alta, por lo que podemos decir que existe una relación lineal entre la edad y llegar tarde, además la covarianza es negativa, lo que indica que la relación es inversamente proporcional."
# Out:
# 'Los resultados del modelo nos indican que la edad es un buen predictor de la llegada tarde, ya que la recta de regresión se ajusta bastante bien a los datos. Además, la correlación es bastante alta, por lo que podemos decir que existe una relación lineal entre la edad y llegar tarde, además la covarianza es negativa, lo que indica que la relación es inversamente proporcional.'

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
datos = pd.read_csv("vehicles.csv")

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
lista_variables = ["Year", "Cylinders", "Fuel Barrels/Year", "Combined MPG", "Fuel Cost/Year"]
for i in lista_variables:
    print(f"La correlación entre {i} y CO2 Emission Grams/Mile es {datos[i].corr(datos['CO2 Emission Grams/Mile'])}")
# Out:
# La correlación entre Year y CO2 Emission Grams/Mile es -0.22229960295054235
# La correlación entre Cylinders y CO2 Emission Grams/Mile es 0.7523925537297473
# La correlación entre Fuel Barrels/Year y CO2 Emission Grams/Mile es 0.9861886621428715
# La correlación entre Combined MPG y CO2 Emission Grams/Mile es -0.926229038933645
# La correlación entre Fuel Cost/Year y CO2 Emission Grams/Mile es 0.9308651512201839

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
X = [lista_variables]
for i in lista_variables:
        X = datos[i].values.reshape(-1,1)
        Y = datos["CO2 Emission Grams/Mile"].values.reshape(-1,1)
        reg = LinearRegression().fit(X, Y)

"Estoy usando una regresión lineal que se asemeja bastante excepto en el caso de combined MPG, donde la relación es más bien exponencial inversa"
# Out:
# 'Estoy usando una regresión lineal que se asemeja bastante excepto en el caso de combined MPG, donde la relación es más bien exponencial inversa'

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
X = [lista_variables]
for i in lista_variables:
        X = datos[i].values.reshape(-1,1)
        Y = datos["CO2 Emission Grams/Mile"].values.reshape(-1,1)
        reg = LinearRegression().fit(X, Y)
        plt.scatter(X, Y)
        plt.plot(X, reg.predict(X), color='red', linewidth=3)
        plt.xlabel(i); plt.ylabel("CO2 Emission Grams/Mile") ; plt.show()

# %% [markdown]
# ## Bonus Challenge: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
datos = pd.DataFrame({'X': [1,3,4,6,8,9,11,14], 'Y': [1,2,4,4,5,7,8,13]})

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
plt.scatter(datos['X'], datos['Y'],  color='black')
plt.xlabel("X") ; plt.ylabel("Y") ; plt.show()

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
X = datos['X'].values.reshape(-1,1)
Y = datos['Y'].values.reshape(-1,1)
reg = LinearRegression().fit(X, Y)
plt.scatter(X, Y)
plt.plot(X, reg.predict(X), color='red', linewidth=3)
plt.xlabel("X") ; plt.ylabel("Y") ; plt.show()
"Se ve que la relación es lineal, por lo que podemos usar una regresión lineal para predecir Y a partir de X."
# Out:
# 'Se ve que la relación es lineal, por lo que podemos usar una regresión lineal para predecir Y a partir de X.'

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
media = datos.mean() ; desviacion = datos.std()
datos = datos[(datos - media).abs() <= 3*desviacion]
datos = datos.dropna()
X = datos['X'].values.reshape(-1,1)
Y = datos['Y'].values.reshape(-1,1)
reg = LinearRegression().fit(X, Y)
plt.scatter(X, Y)
plt.plot(X, reg.predict(X), color='red', linewidth=3)
plt.xlabel("X") ; plt.ylabel("Y") ; plt.show()

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
"La regresión lineal se ve afectada por los valores atípicos, por lo que es necesario eliminarlos para obtener un modelo más preciso,he eliminado los datos que se alejan más de 3 veces de la desviación típica de los datos."
# Out:
# 'La regresión lineal se ve afectada por los valores atípicos, por lo que es necesario eliminarlos para obtener un modelo más preciso,he eliminado los datos que se alejan más de 3 veces de la desviación típica de los datos.'
